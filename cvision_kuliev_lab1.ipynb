# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline


def get_histogram(image):
    pixels = list(image.getdata())
    histogram = [0 for i in range(256)]
    for pixel in pixels:
        histogram[pixel] += 1
    return histogram


def plot_hist(hist, name, color):
    names = range(256)
    plt.bar(names, hist, color=color, width=1.0)
    plt.title(name)
    plt.show()

# %%
image = Image.open('monalisa.jpeg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=182x276 at 0x10A7DEA90>

# %%
r, g, b = image.split() 

r_histogram = get_histogram(r)
g_histogram = get_histogram(g)
b_histogram = get_histogram(b)

# %%
plot_hist(r_histogram, 'Red Channel', color = 'red')

# %%
plot_hist(g_histogram, 'Green Channel', color = 'green')

# %%
plot_hist(b_histogram, 'Blue Channel', color = 'blue')
